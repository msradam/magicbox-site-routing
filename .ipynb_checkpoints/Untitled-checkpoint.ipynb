# %%
URL = "https://healthsites.io/api/v1/healthsites/facilities?"

# %%
import requests

# %%
PARAMS = {'extent': "4.0,12.0,12.0,18.0", 'format': "json"}

# %%
r = requests.get(url = URL, params = PARAMS)

# %%
data = r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-42-47690001e107> in <module>
# ----> 1 data = r.json()
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
# ...

# %%
print(data)
# Out:
# [{'raw-source': 'https://data.humdata.org/dataset/nigeria-healthsites', 'source_url': 'http://nmis.mdgs.gov.ng/', 'upstream': 'Nigeria MDG Information System¶32370', 'name': '!×××', 'completeness': '35.29%', 'uuid': '938443c6761a4b1fa94ac1ce9c254a56', 'date_modified': '2016-05-23T08:56:39.415Z', 'source': 'Nigeria MDG information system', 'version': 4, 'nature-of-facility': 'Health Post', 'geom': [9.401260614, 12.32250273]}, {'raw-source': 'https://data.humdata.org/dataset/nigeria-healthsites', 'source_url': 'http://nmis.mdgs.gov.ng/', 'upstream': 'Nigeria MDG Information System¶26429', 'name': 'ABBAS BASIC HEALTH CLINIC', 'completeness': '35.29%', 'uuid': '7c725470e6534b13a1c2afa04c5dc7bc', 'date_modified': '2016-05-23T08:56:39.415Z', 'source': 'Nigeria MDG information system', 'version': 4, 'nature-of-facility': 'Clinic', 'geom': [8.13693721, 12.15342448]}, {'raw-source': 'https://data.humdata.org/dataset/nigeria-healthsites', 'source_url': 'http://nmis.mdgs.gov.ng/', 'upstream': '
# ...
